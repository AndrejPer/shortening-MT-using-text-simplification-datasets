# %%
from datasets import load_dataset

raw_datasets = load_dataset("kde4", lang1="en", lang2="fr")
# Out:
# Using custom data configuration en-fr-lang1=en,lang2=fr
# Found cached dataset kde4 (/Users/Andrej/.cache/huggingface/datasets/kde4/en-fr-lang1=en,lang2=fr/0.0.0/243129fb2398d5b0b4f7f6831ab27ad84774b7ce374cf10f60f6e1ff331648ac)
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 121.87it/s]

# %%
raw_dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 raw_dataset
#
# NameError: name 'raw_dataset' is not defined

# %%
train = {'translation': [{'en': 'No', 'sr': 'Ne.'}]}
test = {'translation': [{'en': 'Yes.', 'sr': 'Da.'}]}

# %%
from datasets.dataset_dict import DatasetDict
from datasets import Dataset
list = [train, test]
dataset = Dataset.from_list(list)

# %%
dataset1 = Dataset.from_dict(train)
dataset2 = Dataset.from_dict(test)

# %%
dataset = DatasetDict({'train': dataset1, 'test':dataset2})

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 1
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 1
#     })
# })
